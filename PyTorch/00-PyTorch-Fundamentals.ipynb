# %%
# !nvidia-smi
# Out:
# Mon Jan 26 15:37:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.80                 Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   39C    P8              7W /   78W |     834MiB /   6144MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1988    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A            3164    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A            3812    C+G   ...0_x64__8wekyb3d8bbwe\Time.exe      N/A      |
# |    0   N/A  N/A            6572    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            7232    C+G   ....0.3719.93\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            7708    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A            7964    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            7972    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A            8036    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A            8084    C+G   ...cw5n1h2txyewy\WidgetBoard.exe      N/A      |
# |    0   N/A  N/A            9064    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10764    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           11880    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           14884    C+G   ....0.3719.93\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15020    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           19264    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           20556    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20680    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           22388    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           24788    C+G   ...a\Roaming\Spotify\Spotify.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(f"torch: {torch.__version__}")
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
# Out:
# torch: 2.7.1+cu118
# numpy: 2.3.5
# pandas: 3.0.0

# %% [markdown]
# ## Introduction to tensros
#
# ### Creating tensors

# %% [markdown]
# ### Scalar

# %%
# scalar

scalar = torch.tensor(10)
scalar
# Out:
# tensor(10)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 10

# %%
type(scalar), type(scalar.item())
# Out:
# (torch.Tensor, int)

# %% [markdown]
# ### Vector

# %%
vector = torch.tensor([10, 10])
vector
# Out:
# tensor([10, 10])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])
