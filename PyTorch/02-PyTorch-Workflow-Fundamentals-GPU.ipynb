# %% [markdown]
# ## Let's create Linear Regression Model and use GPU for training, evaluations and inference

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

torch.__version__
# Out:
# '2.7.1+cu118'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data

# %%
weight = 7
bias = 3

start = 0
end = 1
step = 0.02

X = torch.arange(start, end, step).unsqueeze(dim=1)
y = weight * X + bias

X.device, y.device, len(X), len(y), X[:10], y[:10]
# Out:
# (device(type='cpu'),
#  device(type='cpu'),
#  50,
#  50,
#  tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[3.0000],
#          [3.1400],
#          [3.2800],
#          [3.4200],
#          [3.5600],
#          [3.7000],
#          [3.8400],
#          [3.9800],
#          [4.1200],
#          [4.2600]]))

# %% [markdown]
# ### Split data

# %%
# 80% training and 20% testin
train_split = int(len(X) * 0.8)

X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %% [markdown]
# ### Visualize data

# %%
def plot_predictions(train_data = X_train,
                     train_label = y_train,
                     test_data = X_test,
                     test_label = y_test,
                     predictions = None):
    
    """
    Plots the training, test and predictions
    """

    plt.scatter(train_data, train_label, c='r', s=4, label="Training data")

    plt.scatter(test_data, test_label, c='b', s=4, label="Testing data")

    if predictions is not None :

        plt.scatter(test_data, predictions, c='black', s=4, label="Predictions")

    plt.legend(prop={"size" : 14})

# %%
plot_predictions(train_data=X_train,
                 train_label=y_train,
                 test_data=X_test,
                 test_label=y_test)

# %% [markdown]
# ## Defining model architecture

# %%
class LinearRegressionModelV2(nn.Module):

    def __init__(self):

        super().__init__()

        self.linear_layer = nn.Linear(in_features=1,
                                      out_features=1)
        
    def forward(self, x: torch.tensor) -> torch.tensor:

        return self.linear_layer(x)

# %%
torch.manual_seed(42)

model_1 = LinearRegressionModelV2()
model_1, model_1.state_dict()
# Out:
# (LinearRegressionModelV2(
#    (linear_layer): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  OrderedDict([('linear_layer.weight', tensor([[0.7645]])),
#               ('linear_layer.bias', tensor([0.8300]))]))

# %% [markdown]
# ### Let's check is model is using cpu

# %%
print(f"Model is on: {next(model_1.parameters()).device}")
print(f"Model parameters are: {next(model_1.parameters()).dtype}")
# Out:
# Model is on: cpu
# Model parameters are: torch.float32

# %% [markdown]
# ### Let's use GPU for this model

# %%
model_1.to(device)
print(f"Model is on: {next(model_1.parameters()).device}")
# Out:
# Model is on: cuda:0

# %% [markdown]
# ### Loss function and optimizer for model

# %%
loss_fn = nn.L1Loss()

optimizer = torch.optim.SGD(params=model_1.parameters(),
                            lr=0.01)

# %% [markdown]
# ### Put data on the GPU

# %%
X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)

X_train.device, y_train.device, X_test.device, y_test.device
# Out:
# (device(type='cuda', index=0),
#  device(type='cuda', index=0),
#  device(type='cuda', index=0),
#  device(type='cuda', index=0))

# %%
def Fit(epochs):

    train_loss_values = []
    test_loss_values = []
    epoch_count = []

    for epoch in range(epochs):

        model_1.train()

        train_preds = model_1(X_train)
        
        train_loss = loss_fn(train_preds, y_train)

        optimizer.zero_grad()

        train_loss.backward()

        optimizer.step()

        ## Testing

        model_1.eval()

        with torch.inference_mode():

            test_preds = model_1(X_test)
            test_loss = loss_fn(test_preds, y_test)

            if epoch % 10 == 0:

                train_loss_values.append(train_loss.detach())
                test_loss_values.append(test_loss.detach())
                epoch_count.append(epoch)

                print(f"Epoch: {epoch} -----| MAE Train Loss: {train_loss} -----| MAE Test Loss: {test_loss}")

    return epoch_count, train_loss_values, test_loss_values

# %%
epoch_count, train_loss_values, test_loss_values = Fit(100)
# Out:
# Epoch: 0 -----| MAE Train Loss: 1.0600006580352783 -----| MAE Test Loss: 3.0155587196350098
# Epoch: 10 -----| MAE Train Loss: 1.038016438484192 -----| MAE Test Loss: 2.9527909755706787
# Epoch: 20 -----| MAE Train Loss: 1.0193384885787964 -----| MAE Test Loss: 2.895566701889038
# Epoch: 30 -----| MAE Train Loss: 1.001399040222168 -----| MAE Test Loss: 2.8389575481414795
# Epoch: 40 -----| MAE Train Loss: 0.9847170114517212 -----| MAE Test Loss: 2.7848458290100098
# Epoch: 50 -----| MAE Train Loss: 0.9703441858291626 -----| MAE Test Loss: 2.7344796657562256
# Epoch: 60 -----| MAE Train Loss: 0.955971360206604 -----| MAE Test Loss: 2.6841137409210205
# Epoch: 70 -----| MAE Train Loss: 0.9435605406761169 -----| MAE Test Loss: 2.638183355331421
# Epoch: 80 -----| MAE Train Loss: 0.9322705268859863 -----| MAE Test Loss: 2.594154119491577
# Epoch: 90 -----| MAE Train Loss: 0.9209806323051453 -----| MAE Test Loss: 2.5501248836517334

# %%
train_loss_values
# Out:
# [tensor(1.0600, device='cuda:0'),
#  tensor(1.0380, device='cuda:0'),
#  tensor(1.0193, device='cuda:0'),
#  tensor(1.0014, device='cuda:0'),
#  tensor(0.9847, device='cuda:0'),
#  tensor(0.9703, device='cuda:0'),
#  tensor(0.9560, device='cuda:0'),
#  tensor(0.9436, device='cuda:0'),
#  tensor(0.9323, device='cuda:0'),
#  tensor(0.9210, device='cuda:0')]

# %% [markdown]
# ### Plot the losses

# %%
plt.plot(epoch_count, train_loss_values, label="Training Loss")
plt.plot(epoch_count, test_loss_values, label="Testing Loss")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 plt.plot(epoch_count, train_loss_values, label="Training Loss")
#       2 plt.plot(epoch_count, test_loss_values, label="Testing Loss")
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\matplotlib\axes\_base.py:484, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     482 if len(xy) == 2:
#     483     x = _check_1d(xy[0])
# --> 484     y = _check_1d(xy[1])
#     485 else:
#     486     x, y = index_of(xy[-1])
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\matplotlib\cbook.py:1368, in _check_1d(x)
#    1362 # plot requires `shape` and `ndim`.  If passed an
#    1363 # object that doesn't provide them, then force to numpy array.
#    1364 # Note this will strip unit information.
#    1365 if (not hasattr(x, 'shape') or
#    1366         not hasattr(x, 'ndim') or
#    1367         len(x.shape) < 1):
# -> 1368     return np.atleast_1d(x)
#    1369 else:
#    1370     return x
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\numpy\_core\shape_base.py:63, in atleast_1d(*arys)
#      23 """
#      24 Convert inputs to arrays with at least one dimension.
#      25
#    (...)     60
#      61 """
#      62 if len(arys) == 1:
# ---> 63     result = asanyarray(arys[0])
#      64     if result.ndim == 0:
#      65         result = result.reshape(1)
#
# File d:\Work\Coding\Machine-Learning\PyTorch\.venv\Lib\site-packages\torch\_tensor.py:1225, in Tensor.__array__(self, dtype)
#    1223     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1224 if dtype is None:
# -> 1225     return self.numpy()
#    1226 else:
#    1227     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
